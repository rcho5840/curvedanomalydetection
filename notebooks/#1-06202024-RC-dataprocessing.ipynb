# %%
import cv2 as cv
import numpy as np
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from keras.applications.vgg16 import VGG16
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix
# Out:
# WARNING:tensorflow:From c:\Users\randy\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from src.processing import findunique

findunique.uniquesets('F:\Data\*')
# Out:
#  100% |█████████████████| 353/353 [51.6ms elapsed, 0s remaining, 6.8K samples/s]
# Computing embeddings...
#  100% |█████████████████| 353/353 [3.6m elapsed, 0s remaining, 1.7 samples/s]
# Computing unique samples...
# Generating index for 353 embeddings...
# Index complete
# threshold: 1.000000, kept: 2, target: 150
# threshold: 0.500000, kept: 7, target: 150
# threshold: 0.250000, kept: 24, target: 150
# threshold: 0.125000, kept: 85, target: 150
# threshold: 0.062500, kept: 297, target: 150
# threshold: 0.093750, kept: 162, target: 150
# threshold: 0.109375, kept: 115, target: 150
# threshold: 0.101562, kept: 137, target: 150
# threshold: 0.097656, kept: 148, target: 150
# threshold: 0.095703, kept: 153, target: 150
# threshold: 0.096680, kept: 151, target: 150
# threshold: 0.097168, kept: 149, target: 150
# threshold: 0.096924, kept: 150, target: 150
# Uniqueness computation complete
# Directory 'F:\Data\Anomaly\ba\new' already exists; export will be merged with existing files
# ...

# %%
from src.processing import splitdata

splitdata = splitdata.splitdata('F:\Data', 'F:\CleanData')
# Out:
# Copying files: 957 files [00:08, 107.72 files/s]

# %%
from src.processing import formatting

X_train, y_train = formatting.formatting('F:/CleanData/train')
X_test, y_test = formatting.formatting('F:/CleanData/test')
# Out:
# F:/CleanData/train\Anomaly\chairanomalyframes_001.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_002.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_003.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_006.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_007.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_008.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_012.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_015.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_018.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_019.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_020.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_027.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_028.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_030.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_034.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_055.jpg
# F:/CleanData/train\Anomaly\chairanomalyframes_056.jpg
# ...

# %%
X_train.size
# Out:
# 150405120

# %%
import os
import numpy as np
os.chdir(r'F:\CleanData\train')
np.save("X_train.npy", X_train)
np.save("Y_train.npy", y_train)
