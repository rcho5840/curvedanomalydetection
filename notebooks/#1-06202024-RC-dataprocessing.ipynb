# %%
import cv2 as cv
import numpy as np
import os

# %%
from src.processing import findunique
import fiftyone as fo
import fiftyone.brain as fob

findunique.findunique('C:/Users/randy/OneDrive/Documents/AnomalyDetection/videos')
# Out:
#  100% |███████████████| 2132/2132 [273.2ms elapsed, 0s remaining, 7.8K samples/s]
# Computing embeddings...
#  100% |███████████████| 2132/2132 [22.3m elapsed, 0s remaining, 1.6 samples/s]
# Computing unique samples...
# Generating index for 2132 embeddings...
# Index complete
# threshold: 1.000000, kept: 5, target: 30
# threshold: 0.500000, kept: 122, target: 30
# threshold: 0.750000, kept: 17, target: 30
# threshold: 0.625000, kept: 41, target: 30
# threshold: 0.687500, kept: 27, target: 30
# threshold: 0.656250, kept: 31, target: 30
# threshold: 0.671875, kept: 27, target: 30
# threshold: 0.664062, kept: 29, target: 30
# c:\Users\randy\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\extmath.py:192: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# threshold: 0.660156, kept: 29, target: 30
# threshold: 0.658203, kept: 30, target: 30
# Uniqueness computation complete
# <style>
# ...
