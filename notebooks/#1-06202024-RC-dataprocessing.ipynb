# %%
import cv2 as cv
import numpy as np
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from keras.applications.vgg16 import VGG16
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix
# Out:
# WARNING:tensorflow:From c:\Users\randy\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from src.processing import findunique

findunique.uniquesets('F:/CleanData/*')

# %%
from src.processing import findunique

findunique.uniquesets('F:/NewCleanData/*')
# Out:
#  100% |███████████████| 7382/7382 [835.2ms elapsed, 0s remaining, 8.9K samples/s]
# Computing embeddings...
#  100% |███████████████| 7382/7382 [1.3h elapsed, 0s remaining, 1.6 samples/s]
# Computing unique samples...
# Generating index for 7382 embeddings...
# Index complete
# c:\Users\randy\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\extmath.py:192: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# threshold: 1.000000, kept: 5, target: 500
# threshold: 0.500000, kept: 33, target: 500
# threshold: 0.250000, kept: 135, target: 500
# threshold: 0.125000, kept: 624, target: 500
# threshold: 0.187500, kept: 257, target: 500
# threshold: 0.156250, kept: 396, target: 500
# threshold: 0.140625, kept: 482, target: 500
# threshold: 0.132812, kept: 549, target: 500
# threshold: 0.136719, kept: 507, target: 500
# threshold: 0.138672, kept: 490, target: 500
# threshold: 0.137695, kept: 500, target: 500
# Uniqueness computation complete
# ...

# %%
from src.processing import split

split.split('F:/CleanData', 'F:/CleanDataSplit')
# Out:
# Copying files: 957 files [00:48, 19.66 files/s]

# %%
from src.processing import formatting

X_train, y_train = formatting.formatting('F:/CleanDataSplit/train/*')
X_test, y_test = formatting.formatting('F:/CleanDataSplit/test/*')
X_val, y_val = formatting.formatting('F:/CleanDataSplit/val/*')
# Out:
# Anomaly
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_001.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_002.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_003.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_006.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_007.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_012.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_015.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_018.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_019.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_020.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_027.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_028.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_030.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_034.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_055.jpg
# F:/CleanDataSplit/train\Anomaly\chairanomalyframes_056.jpg
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2,2, figsize = (20,20))
mission = [6,7,37, 34]
j = 0
for i, ax in enumerate(ax.flat):
    ax.imshow(X_train[mission[j]])
    ax.title.set_text(y_train[mission[j]])
    ax.axis("off")
    j = j + 1
plt.tight_layout
plt.show()

# %%
X_test.shape
# Out:
# (98, 256, 256, 3)

# %%
import numpy as np
import os
os.chdir('F:/CleanDataSplit')

np.save('X_train.npy', X_train)
np.save('y_train.npy', y_train)

np.save('X_test.npy', X_test)
np.save('y_test.npy', y_test)

np.save('X_val.npy', X_val)
np.save('y_val.npy', y_val)
