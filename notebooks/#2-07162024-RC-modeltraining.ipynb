# %%
import numpy as np
import os
os.chdir(r'F:\CleanDataSplit')
X_train  = np.load("X_train.npy")
y_train  = np.load("y_train.npy")

X_test = np.load("X_test.npy")
y_test = np.load("Y_test.npy")

X_val = np.load("X_val.npy")
y_val = np.load("y_val.npy")

# %%
import numpy as np
import os
os.chdir(r'F:\NewCleanDataSplit')
X_train_new  = np.load("X_train_new.npy")
y_train_new  = np.load("y_train_new.npy")

X_test_new = np.load("X_test_new.npy")
y_test_new  = np.load("Y_test_new.npy")

X_val_new = np.load("X_val_new.npy")
y_val_new = np.load("y_val_new.npy")

# %%
from src.training import cnn
import pickle

hist, cnn = cnn.cnn(X_train, y_train, X_val, y_val)

with open ('C\Users\randy\OneDrive\Desktop\CS\curvedanomalydetection\conf\cnn', 'wb') as f:
        pickle.dump(cnn, f)
# Out:
# WARNING:tensorflow:From c:\Users\randy\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\randy\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\randy\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\randy\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# ...

# %%
from src.training import cnn
import pickle

hist, newcnn = cnn.cnn(X_train_new, y_train_new, X_val_new, y_val_new)

with open (r'C:\Users\randy\OneDrive\Desktop\CS\curvedanomalydetection\newcnn', 'wb') as f:
        pickle.dump(newcnn, f)
# Out:
# WARNING:tensorflow:From c:\Users\randy\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\randy\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\randy\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\randy\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# ...

# %%
from src.evaluation import cnnvisualization

cnnvisualization.cnnvisualization(hist, 'loss', 'Training Loss', 'val_loss', 'Validation Loss', 'Loss Graphs')
cnnvisualization.cnnvisualization(hist, 'accuracy', 'Training Accuracy', 'val_accuracy', 'Validation Accuracy', 'Accuracy Graphs')

# %%
pre = Precision().update_state(testing_images, testing_labels)
re = Recall().update_state(testing_images, testing_labels)
acc = BinaryAccuracy().update_state(testing_images, testing_labels)

print(f'Precision: {pre.result().numpy()}, Recall: {re.result().numpy()}, Result: {acc.result().numpy()}')
